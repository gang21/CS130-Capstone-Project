# %%
import requests
import json

url = "https://api.arliai.com/v1/chat/completions"

payload = json.dumps({
  "model": "Meta-Llama-3.1-8B-Instruct",
  "messages": [
    {"role": "system", "content": "You are a helpful assistant."},
    {"role": "user", "content": "Hello!"},
    {"role": "assistant", "content": "Hi!, how can I help you today?"},
    {"role": "user", "content": "Can you generate a good opening line for a speech about the importance of education?"},
  ],
  "repetition_penalty": 1.1,
  "temperature": 0.7,
  "top_p": 0.9,
  "top_k": 40,
  "max_tokens": 1024,
  "stream": True
})
headers = {
  'Content-Type': 'application/json',
  'Authorization': f"Bearer e975ff02-0e30-4bc5-8c65-d29e5f1fe3ba"
}

response = requests.request("POST", url, headers=headers, data=payload)

# %%
response.text
# Out:
# 'data: {"id":"chat-255e607e972d49cf8ef6678e71ec396d","object":"chat.completion.chunk","created":1729880053,"model":"Meta-Llama-3.1-8B-Instruct","choices":[{"index":0,"delta":{"role":"assistant"},"logprobs":null,"finish_reason":null}]}\n\ndata: {"id":"chat-255e607e972d49cf8ef6678e71ec396d","object":"chat.completion.chunk","created":1729880053,"model":"Meta-Llama-3.1-8B-Instruct","choices":[{"index":0,"delta":{"content":""},"logprobs":null,"finish_reason":null}]}\n\ndata: {"id":"chat-255e607e972d49cf8ef6678e71ec396d","object":"chat.completion.chunk","created":1729880053,"model":"Meta-Llama-3.1-8B-Instruct","choices":[{"index":0,"delta":{"content":""},"logprobs":null,"finish_reason":null}]}\n\ndata: {"id":"chat-255e607e972d49cf8ef6678e71ec396d","object":"chat.completion.chunk","created":1729880053,"model":"Meta-Llama-3.1-8B-Instruct","choices":[{"index":0,"delta":{"content":""},"logprobs":null,"finish_reason":null}]}\n\ndata: {"id":"chat-255e607e972d49cf8ef6678e71ec396d","object":"chat.completion.chunk","created":1729880053,"model":"Meta-Llama-3.1-8B-Instruct","choices":[{"index":0,"delta":{"content":"Here\'s a "},"logprobs":null,"finish_reason":null}]}\n\ndata: {"id":"chat-255e607e972d49cf8ef6678e71ec396d","object":"chat.completion.chunk","created":1729880053,"model":"Meta-Llama-3.1-8B-Instruct","choices":[{"index":0,"delta":{"content":"potentia"},"logprobs":null,"finish_reason":null}]}\n\ndata: {"id":"chat-255e607e972d49cf8ef6678e71ec396d","object":"chat.completion.chunk","created":1729880053,"model":"Meta-Llama-3.1-8B-Instruct","choices":[{"index":0,"delta":{"content":"l ope"},"logprobs":null,"finish_reason":null}]}\n\ndata: {"id":"chat-255e607e972d49cf8ef6678e71ec396d","object":"chat.completion.chunk","created":1729880053,"model":"Meta-Llama-3.1-8B-Instruct","choices":[{"index":0,"delta":{"content":"nin"},"logprobs":null,"finish_reason":null}]}\n\ndata: {"id":"chat-255e607e972d49cf8ef6678e71ec396d","object":"chat.completion.chunk","created":1729880053,"model":"Meta-Llama-3.1-8B-Instruct","choices":[{"index":0,"delta":{"content":"g"},"logprobs":null,"finish_reason":null}]}\n\ndata: {"id":"chat-255e607e972d49cf8ef6678e71ec396d","object":"chat.completion.chunk","created":1729880053,"model":"Meta-Llama-3.1-8B-Instruct","choices":[{"index":0,"delta":{"content":" line"},"logprobs":null,"finish_reason":null}]}\n\ndata: {"id":"chat-255e607e972d49cf8ef6678e71ec396d","object":"chat.completion.chunk","created":1729880053,"model":"Meta-Llama-3.1-8B-Instruct","choices":[{"index":0,"delta":{"content":":"},"logprobs":null,"finish_reason":null}]}\n\ndata: {"id":"chat-255e607e972d49cf8ef6678e71ec396d","object":"chat.completion.chunk","created":1729880053,"model":"Meta-Llama-3.1-8B-Instruct","choices":[{"index":0,"delta":{"content":"\\n\\n\\""},"logprobs":null,"finish_reason":null}]}\n\ndata: {"id":"chat-255e607e972d49cf8ef6678e71ec396d","object":"chat.completion.chunk","created":1729880053,"model":"Meta-Llama-3.1-8B-Instruct","choices":[{"index":0,"delta":{"content":"Today,"},"logprobs":null,"finish_reason":null}]}\n\ndata: {"id":"chat-255e607e972d49cf8ef6678e71ec396d","object":"chat.completion.chunk","created":1729880053,"model":"Meta-Llama-3.1-8B-Instruct","choices":[{"index":0,"delta":{"content":" we"},"logprobs":null,"finish_reason":null}]}\n\ndata: {"id":"chat-255e607e972d49cf8ef6678e71ec396d","object":"chat.completion.chunk","created":1729880053,"model":"Meta-Llama-3.1-8B-Instruct","choices":[{"index":0,"delta":{"content":" sta"},"logprobs":null,"finish_reason":null}]}\n\ndata: {"id":"chat-255e607e972d49cf8ef6678e71ec396d","object":"chat.completion.chunk","created":1729880053,"model":"Meta-Llama-3.1-8B-Instruct","choices":[{"index":0,"delta":{"content":"nd at the "},"logprobs":null,"finish_reason":null}]}\n\ndata: {"id":"chat-255e607e972d49cf8ef6678e71ec396d","object":"chat.completion.chunk","created":1729880053,"model":"Meta-Llama-3.1-8B-Instruct","choices":[{"index":0,"delta":{"content":"thr"},"logprobs":null,"finish_reason":null}]}\n ...

# %%
data = response.text
lines = data.split('\n')

# Filter out non-JSON parts and parse JSON objects
json_objects = [json.loads(line[6:]) for line in lines if line.startswith('data: {')]

# Pretty-print each JSON object
for obj in json_objects:
    print(json.dumps(obj, indent=4))
# Out:
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "role": "assistant"
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": ""
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": ""
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": ""
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": "Here's a "
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": "potentia"
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": "l ope"
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": "nin"
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": "g"
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": " line"
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": ":"
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": "\n\n\""
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": "Today,"
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": " we"
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": " sta"
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": "nd at the "
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": "thr"
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": "eshold of "
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": "limitless poss"
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": "i"
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": "biliti"
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": "es, "
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": "where the b"
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": "oun"
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": "darie"
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": "s o"
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": "f what is a"
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": "chie"
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": "vable are "
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": "str"
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": "etch"
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": "ed by "
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": "the"
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": " power of "
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": "know"
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": "ledg"
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": "e and th"
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": "e c"
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": "ourage"
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": " to "
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": "lear"
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": "n.\"\n\n"
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": "This "
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": "lin"
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": "e ai"
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": "ms"
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": " to s"
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": "et "
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": "a tone of"
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": " opt"
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": "imism and em"
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": "p"
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": "owerment, em"
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": "phas"
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": "izing"
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": " the "
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": "idea that "
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": "educ"
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": "atio"
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": "n has the "
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": "pot"
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": "ential "
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": "to unl"
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": "ock great oppo"
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": "rtun"
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": "ities a"
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": "nd cha"
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": "nge"
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": " live"
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": "s.\n\n"
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": "Would"
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": " yo"
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": "u l"
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": "ike me t"
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": "o sug"
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": "gest some v"
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": "ari"
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": "ation"
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": "s or "
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": "help"
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": " with"
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": " th"
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": "e re"
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": "st of t"
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": "h"
#             },
#             "logprobs": null,
#             "finish_reason": null
#         }
#     ]
# }
# {
#     "id": "chat-255e607e972d49cf8ef6678e71ec396d",
#     "object": "chat.completion.chunk",
#     "created": 1729880053,
#     "model": "Meta-Llama-3.1-8B-Instruct",
#     "choices": [
#         {
#             "index": 0,
#             "delta": {
#                 "content": "e speech?"
#             },
#             "logprobs": null,
#             "finish_reason": "stop",
#             "stop_reason": null
#         }
#     ]
# }

# %%
json_objects
# Out:
# [{'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'role': 'assistant'},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': ''},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': ''},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': ''},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': "Here's a "},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': 'potentia'},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': 'l ope'},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': 'nin'},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': 'g'},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': ' line'},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': ':'},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': '\n\n"'},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': 'Today,'},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': ' we'},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': ' sta'},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': 'nd at the '},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': 'thr'},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': 'eshold of '},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': 'limitless poss'},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': 'i'},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': 'biliti'},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': 'es, '},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': 'where the b'},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': 'oun'},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': 'darie'},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': 's o'},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': 'f what is a'},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': 'chie'},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': 'vable are '},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': 'str'},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': 'etch'},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': 'ed by '},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': 'the'},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': ' power of '},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': 'know'},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': 'ledg'},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': 'e and th'},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': 'e c'},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': 'ourage'},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': ' to '},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': 'lear'},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': 'n."\n\n'},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': 'This '},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': 'lin'},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': 'e ai'},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': 'ms'},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': ' to s'},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': 'et '},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': 'a tone of'},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': ' opt'},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': 'imism and em'},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': 'p'},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': 'owerment, em'},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': 'phas'},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': 'izing'},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': ' the '},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': 'idea that '},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': 'educ'},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': 'atio'},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': 'n has the '},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': 'pot'},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': 'ential '},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': 'to unl'},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': 'ock great oppo'},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': 'rtun'},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': 'ities a'},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': 'nd cha'},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': 'nge'},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': ' live'},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': 's.\n\n'},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': 'Would'},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': ' yo'},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': 'u l'},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': 'ike me t'},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': 'o sug'},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': 'gest some v'},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': 'ari'},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': 'ation'},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': 's or '},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': 'help'},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': ' with'},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': ' th'},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': 'e re'},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': 'st of t'},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': 'h'},
#     'logprobs': None,
#     'finish_reason': None}]},
#  {'id': 'chat-255e607e972d49cf8ef6678e71ec396d',
#   'object': 'chat.completion.chunk',
#   'created': 1729880053,
#   'model': 'Meta-Llama-3.1-8B-Instruct',
#   'choices': [{'index': 0,
#     'delta': {'content': 'e speech?'},
#     'logprobs': None,
#     'finish_reason': 'stop',
#     'stop_reason': None}]}]

# %%
import json

# Assuming 'response' is a Response object
response_dict = response.json()
print(json.dumps(response_dict, indent=4))
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~/Desktop/UCT_2024/THESIS/.conda/lib/python3.11/site-packages/requests/models.py:974, in Response.json(self, **kwargs)
#     973 try:
# --> 974     return complexjson.loads(self.text, **kwargs)
#     975 except JSONDecodeError as e:
#     976     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     977     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~/Desktop/UCT_2024/THESIS/.conda/lib/python3.11/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File ~/Desktop/UCT_2024/THESIS/.conda/lib/python3.11/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File ~/Desktop/UCT_2024/THESIS/.conda/lib/python3.11/json/decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[7], line 4
#       1 import json
#       3 # Assuming 'response' is a Response object
# ----> 4 response_dict = response.json()
#       5 print(json.dumps(response_dict, indent=4))
#
# File ~/Desktop/UCT_2024/THESIS/.conda/lib/python3.11/site-packages/requests/models.py:978, in Response.json(self, **kwargs)
#     974     return complexjson.loads(self.text, **kwargs)
#     975 except JSONDecodeError as e:
#     976     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     977     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 978     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
# !pip install groq
# Out:
# Collecting groq
#   Downloading groq-0.11.0-py3-none-any.whl.metadata (13 kB)
# Collecting anyio<5,>=3.5.0 (from groq)
#   Downloading anyio-4.6.2.post1-py3-none-any.whl.metadata (4.7 kB)
# Collecting distro<2,>=1.7.0 (from groq)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting httpx<1,>=0.23.0 (from groq)
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting pydantic<3,>=1.9.0 (from groq)
#   Downloading pydantic-2.9.2-py3-none-any.whl.metadata (149 kB)
# Collecting sniffio (from groq)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /Users/adrianmcintosh/Desktop/UCT_2024/THESIS/.conda/lib/python3.11/site-packages (from groq) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /Users/adrianmcintosh/Desktop/UCT_2024/THESIS/.conda/lib/python3.11/site-packages (from anyio<5,>=3.5.0->groq) (3.10)
# Requirement already satisfied: certifi in /Users/adrianmcintosh/Desktop/UCT_2024/THESIS/.conda/lib/python3.11/site-packages (from httpx<1,>=0.23.0->groq) (2024.8.30)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->groq)
#   Downloading httpcore-1.0.6-py3-none-any.whl.metadata (21 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->groq)
#   Using cached h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3,>=1.9.0->groq)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.23.4 (from pydantic<3,>=1.9.0->groq)
#   Downloading pydantic_core-2.23.4-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Downloading groq-0.11.0-py3-none-any.whl (106 kB)
# Downloading anyio-4.6.2.post1-py3-none-any.whl (90 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
# Downloading httpcore-1.0.6-py3-none-any.whl (78 kB)
# Downloading pydantic-2.9.2-py3-none-any.whl (434 kB)
# Downloading pydantic_core-2.23.4-cp311-cp311-macosx_11_0_arm64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 31.4 MB/s eta 0:00:00
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Installing collected packages: sniffio, pydantic-core, h11, distro, annotated-types, pydantic, httpcore, anyio, httpx, groq
# Successfully installed annotated-types-0.7.0 anyio-4.6.2.post1 distro-1.9.0 groq-0.11.0 h11-0.14.0 httpcore-1.0.6 httpx-0.27.2 pydantic-2.9.2 pydantic-core-2.23.4 sniffio-1.3.1

# %%
from groq import Groq

client = Groq(api_key="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")
completion = client.chat.completions.create(
    model="llama3-8b-8192",
    messages=[
        {
            "role": "system",
            "content": "You are a cybersecurity expert. " +
            "You are helping generate a dataset for a training program. "+
            "For every prompt provided, provide only the content requested "+
            "and do not provide any additional information or wording."+
            "Please include example names, email addresses and URLS."+
            "Please do not use things like [example url] or [example email]."

        },
        {
            "role": "user",
            "content": "Please generate an example of a phishing email."
        }
    ],
    temperature=1,
    max_tokens=1024,
    top_p=1,
    stream=False,
    stop=None,
)

print(completion.choices[0].message.content)
# Out:
# Subject: Update Your Account Information
#
# Dear Valued Customer,
#
# We are writing to inform you that our system has detected suspicious activities in your account. As a security measure, we require you to update your account information to continue using our services.
#
# Please click on the link below to update your login credentials and other account details:
#
# https://secure.webbanking.com/updateinfo.aspx
#
# If you do not update your account information within the next 72 hours, your account will be suspended.
#
# Best regards,
# The Web Banking Team
# support@webbanking.com

# %%
from groq import Groq

client = Groq(api_key="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")
completion = client.chat.completions.create(
    model="llama3-8b-8192",
    messages=[
        {
            "role": "system",
            "content": "You are a cybersecurity expert. " +
            "You are helping generate a dataset for a training program. "+
            "You are generating the feedback content that will be used to annotate the dataset."+
            "For every input respond as if you are providing feedback to a user."

        },
        {
            "role": "user",
            "content": "Explain why this is a scam:"+
            """Subject: Update Your Account Information

                Dear Valued Customer,

                We are writing to inform you that our system has detected suspicious activities in your account. As a security measure, we require you to update your account information to continue using our services.

                Please click on the link below to update your login credentials and other account details:

                https://secure.webbanking.com/updateinfo.aspx

                If you do not update your account information within the next 72 hours, your account will be suspended.

                Best regards,
                The Web Banking Team
                support@webbanking.com"""
        }
    ],
    temperature=1,
    max_tokens=1024,
    top_p=1,
    stream=False,
    stop=None,
)

print(completion.choices[0].message.content)
# Out:
# Warning!
#
# This email is likely a phishing scam. Here's why:
#
# 1. **Urgency**: The email creates a sense of urgency by stating that the account will be suspended if the user doesn't update their information within 72 hours. This is a common tactic scammers use to trick victims into acting quickly without thinking.
# 2. **Phishing link**: The link provided is not encrypted (HTTP, not HTTPS) and is not trustworthy. Legitimate companies usually use HTTPS protocol to secure their websites.
# 3. **Suspicious activity**: The email claims that the user's account has been compromised, but it doesn't specify what kind of suspicious activity was detected. This is a red flag, as legitimate companies typically provide more detailed information about the incident.
# 4. **Lack of personalization**: The email doesn't address the user by name, despite claiming to be from the Web Banking Team.
# 5. **Bad grammar and formatting**: The email's writing style and formatting are inconsistent, which is uncommon in official company communications.
# 6. **No direct contact information**: The email only provides a generic support email address (support@webbanking.com) and no phone number or physical address.
#
# To avoid falling victim to this scam, never click on suspicious links or provide sensitive information in response to unsolicited emails. Instead, directly log in to your Web Banking account or contact them through a known phone number or email address to verify the authenticity of the notification.

# %%
from groq import Groq

client = Groq(api_key="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")
completion = client.chat.completions.create(
    model="llama3-8b-8192",
    messages=[
        {
            "role": "system",
            "content": "You are a cybersecurity expert. " +
            "You are helping generate a dataset for a training program. "+
            "For every prompt provided, provide only the content requested "+
            "and do not provide any additional information or wording."+
            "Please include example names, email addresses and URLS."+
            "Please do not use things like [example url] or [example email]."

        },
        {
            "role": "user",
            "content": "Please generate an example of a realistic email that is not a scam ."
        }
    ],
    temperature=1,
    max_tokens=1024,
    top_p=1,
    stream=False,
    stop=None,
)

print(completion.choices[0].message.content)
# Out:
# Here is an example of a realistic email that is not a scam:
#
# Subject: Invitation to our Quarterly Review Meeting
#
# From: John Smith <john.smith@acmeinc.com>
# To: Jane Doe <jane.doe@acmeinc.com>
# Date: March 22, 2023 12:00 PM
# CC: Bob Johnson <bob.johnson@acmeinc.com>, Sarah Lee <sarah.lee@acmeinc.com>
#
# Dear Jane,
#
# We are pleased to invite you to our quarterly review meeting, scheduled for April 12th at 2:00 PM in the Boardroom. The agenda will cover our company's progress and future plans. Your input and participation are highly valued.
#
# To confirm your attendance, please reply to this email by April 5th. If you are unable to attend, please notify us in advance so we can make necessary arrangements.
#
# Best regards,
# John Smith
# Director, Operations

# %%
from groq import Groq

client = Groq(api_key="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")
completion = client.chat.completions.create(
    model="llama3-8b-8192",
    messages=[
        {
            "role": "system",
            "content": "You are a cybersecurity expert. " +
            "You are helping generate a dataset for a training program. "+
            "You are generating the feedback content that will be used to annotate the dataset."+
            "For every input respond as if you are providing feedback to a user."

        },
        {
            "role": "user",
            "content": "Explain why this is not a scam:"+
            """Subject: Invitation to our Quarterly Review Meeting

                From: John Smith <john.smith@acmeinc.com>
                To: Jane Doe <jane.doe@acmeinc.com>
                Date: March 22, 2023 12:00 PM
                CC: Bob Johnson <bob.johnson@acmeinc.com>, Sarah Lee <sarah.lee@acmeinc.com>

                Dear Jane,

                We are pleased to invite you to our quarterly review meeting, scheduled for April 12th at 2:00 PM in the Boardroom. The agenda will cover our company's progress and future plans. Your input and participation are highly valued.

                To confirm your attendance, please reply to this email by April 5th. If you are unable to attend, please notify us in advance so we can make necessary arrangements.

                Best regards,
                John Smith
                Director, Operations"""
        }
    ],
    temperature=1,
    max_tokens=1024,
    top_p=1,
    stream=False,
    stop=None,
)

print(completion.choices[0].message.content)
# Out:
# Great job identifying this email as potentially legitimate!
#
# Here's why I think it's not a scam:
#
# 1. Context: The email is sent by a well-known company, ACME Inc., which provides a sense of authenticity. The sender's email address, john.smith@acmeinc.com, also suggests a legitimate company email address.
# 2. Purpose: The purpose of the email, to invite Jane to a quarterly review meeting, is clear and reasonable. It's a common practice for companies to hold regular meetings to discuss progress and plans.
# 3. Specific details: The email provides specific details about the meeting, including the date, time, location, and agenda. This level of transparency builds trust and suggests that the email is not a phishing attempt.
# 4. Professional tone: The email is written in a professional tone, using formal language and a clear structure. This is consistent with the tone and style of communication typically used by legitimate companies.
# 5. No explicit calls to action: The email does not contain any urgent or explicit calls to action, such as asking Jane to click on a link or provide sensitive information. This reduces the risk of a phishing attack.
#
# Overall, while it's always important to be cautious when receiving unsolicited emails, this one appears to be a legitimate email invitation from a known company.

# %%
# import tqdm
from tqdm import tqdm

# create a for loop of 100 iterations to generate 100 examples of realistic emails that are not scams
real_list = []

for i in tqdm(range(100)):
    completion = client.chat.completions.create(
        model="llama3-8b-8192",
        messages=[
            {
                "role": "system",
                "content": "You are a cybersecurity expert. " +
                "You are helping generate a dataset for a training program. "+
                "For every prompt provided, provide only the content requested "+
                "and do not provide any additional information or wording."+
                "Please include example names, email addresses and URLS."+
                "Please do not use things like [example url] or [example email]."

            },
            {
                "role": "user",
                "content": "Please generate an example of a realistic email that is not a scam ."
            }
        ],
        temperature=1,
        max_tokens=1024,
        top_p=1,
        stream=False,
        stop=None,
    )

    real_list.append(completion.choices[0].message.content)


# create a for loop of 100 iterations to generate 100 examples of phishing emails
scam_list = []

for i in tqdm(range(100)):
    completion = client.chat.completions.create(
        model="llama3-8b-8192",
        messages=[
            {
                "role": "system",
                "content": "You are a cybersecurity expert. " +
                "You are helping generate a dataset for a training program. "+
                "For every prompt provided, provide only the content requested "+
                "and do not provide any additional information or wording."+
                "Please include example names, email addresses and URLS."+
                "Please do not use things like [example url] or [example email]."

            },
            {
                "role": "user",
                "content": "Please generate an example of a phishing email."
            }
        ],
        temperature=1,
        max_tokens=1024,
        top_p=1,
        stream=False,
        stop=None,
    )

    scam_list.append(completion.choices[0].message.content)
# Out:
# 100%|██████████| 100/100 [03:04<00:00,  1.84s/it]
# 100%|██████████| 100/100 [03:49<00:00,  2.30s/it]

# %%
# save the generated emails to a CSV file
import csv

with open('real_emails.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    for real in real_list:
        writer.writerow([real.replace('\n', '\\n')])

with open('scam_emails.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    for scam in scam_list:
        writer.writerow([scam.replace('\n', '\\n')])

# %%
# import tqdm
from tqdm import tqdm

# create a for loop of 100 iterations to generate 100 examples of realistic emails that are not scams
real_text_list = []

for i in tqdm(range(100)):
    completion = client.chat.completions.create(
        model="llama3-8b-8192",
        messages=[
            {
                "role": "system",
                "content": "You are a cybersecurity expert. " +
                "You are helping generate a dataset for a training program. "+
                "For every prompt provided, provide only the content requested "+
                "and do not provide any additional information or wording."+
                "Please include example names, numbers and URLS."+
                "Please do not use things like [example url] or [example email]."+
                "Finally, do not start the response with something like: Here is an example of a realistic message that is not a scam."

            },
            {
                "role": "user",
                "content": "Please generate an example of a realistic SMS or text message that is not a scam ."
            }
        ],
        temperature=1,
        max_tokens=1024,
        top_p=1,
        stream=False,
        stop=None,
    )

    real_text_list.append(completion.choices[0].message.content)


# create a for loop of 100 iterations to generate 100 examples of phishing emails
scam_text_list = []

for i in tqdm(range(100)):
    completion = client.chat.completions.create(
        model="llama3-8b-8192",
        messages=[
            {
                "role": "system",
                "content": "You are a cybersecurity expert. " +
                "You are helping generate a dataset for a training program. "+
                "For every prompt provided, provide only the content requested "+
                "and do not provide any additional information or wording."+
                "Please include example names, numbers and URLS."+
                "Please do not use things like [example url] or [example email]."+
                "Do not start the response with something like: Here is an example of a scam message"

            },
            {
                "role": "user",
                "content": "Please generate an example of a scam text or SMS message."
            }
        ],
        temperature=1,
        max_tokens=1024,
        top_p=1,
        stream=False,
        stop=None,
    )

    scam_text_list.append(completion.choices[0].message.content)
# Out:
# 100%|██████████| 100/100 [02:43<00:00,  1.64s/it]
# 100%|██████████| 100/100 [03:50<00:00,  2.30s/it]

# %%
# save the generated texts to a CSV file
import csv

with open('real_texts.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    for real in real_text_list:
        writer.writerow([real.replace('\n', '\\n')])

with open('scam_texts.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    for scam in scam_text_list:
        writer.writerow([scam.replace('\n', '\\n')])

# %%
# lets make a function for generating the feedback content for the dataset

def generate_feedback_content(prompt,scam=True):
    completion = client.chat.completions.create(
        model="llama3-8b-8192",
        messages=[
            {
                "role": "system",
                "content": "You are a cybersecurity expert. " +
                "You are helping generate a dataset for a training program. "+
                "You are generating the feedback content that will be used to annotate the dataset."+
                "You don't know if the user got it right or wrong, so don't congratulate on a correct answer."+
                "Just say whether it is a scam or not (based on what you are prompted it is or isn't), and then explain why."

            },
            {
                "role": "user",
                "content": 
                "This mesage is a scam." if scam else "This message is not a scam."+
                "Please explain why."+
                "Also, identify the type of scam" if scam else ""+
                f"\n{prompt}"
            }
        ],
        temperature=1,
        max_tokens=1024,
        top_p=1,
        stream=False,
        stop=None,
    )

    return completion.choices[0].message.content.replace('\n', '\\n')

# %%
import pandas as pd
from tqdm import tqdm

def process_emails(input_csv, output_csv, scam=True):
    # read the input CSV file
    real_emails = pd.read_csv(input_csv, header=None)

    # set the column name of the first column to "email content"
    real_emails.columns = ['email_content']

    # create a new column for the feedback content
    tqdm.pandas(desc="Generating feedback content")
    real_emails['feedback_content'] = real_emails['email_content'].progress_apply(lambda x: generate_feedback_content(x, scam))

    # save the new dataframe to the output CSV file
    real_emails.to_csv(output_csv, index=False)

# Example usage
# process_emails('real_emails.csv', 'real_emails_with_feedback.csv', scam=False)
# Out:
# Generating feedback content: 100%|██████████| 100/100 [02:52<00:00,  1.72s/it]

# %%
process_emails('real_emails.csv', 'real_emails_with_feedback.csv', scam=False)
process_emails('scam_emails.csv', 'scam_emails_with_feedback.csv', scam=True)
process_emails('real_texts.csv', 'real_texts_with_feedback.csv', scam=False)
process_emails('scam_texts.csv', 'scam_texts_with_feedback.csv', scam=True)
# Out:
# Generating feedback content: 100%|██████████| 100/100 [02:50<00:00,  1.71s/it]
# Generating feedback content: 100%|██████████| 100/100 [03:56<00:00,  2.37s/it]
# Generating feedback content: 100%|██████████| 100/100 [03:54<00:00,  2.34s/it]
